# %%
import pandas as pd
sample_md = pd.read_csv('combined-map.tsv', sep='\t', index_col=0, dtype=object)
seqs_per_sample = pd.read_csv('../microbiome-data/run1-4/vsearch-100/seqs-per-samples.tsv', sep='\t', index_col=0, dtype=object)

# %%
for e in sample_md.index:
    try:
        print(e, int(float(seqs_per_sample['sequences.per.sample'][e])))
    except KeyError:
        print(e, 0)
# Out:
# 50f400f5.8e55.420b.9a63.4623a5900017 34713
# 3d8ecbcf.31de.4f58.952a.2c7fc438d2a9 0
# 4f5ef0fe.4365.4675.94d2.dd9144222614 0
# 9000e59e.4bd6.41a5.bd6d.1fa5e71a8f54 24322
# 2810ac58.4851.4789.a792.12f0eed210b2 0
# df0fa55d.c268.48f3.8ae9.2e52a808124f 0
# 63200094.189d.4880.beaf.0a041635cab7 46529
# 14406c0f.5000.4edd.9f97.d9f88ea71115 40625
# 2cfcc030.33e9.4f0d.ad96.414079bbee74 0
# 6c502824.4abe.42cb.8408.5871938a9b8b 0
# a9924294.9d6f.44ae.8047.f61ca854931a 5
# abf9d6dd.ee85.4848.8d1a.47d8d55bef35 6
# 38231131.c50c.4db7.835f.5efdf8a95057 480
# 9ed6ca18.aff3.4795.ab4a.1b7af3b839a9 5721
# 5b6671cb.91c1.469c.8871.fea4315a757c 5820
# 03a27c57.cf57.417a.90fe.5b9d5ffb32c0 5921
# f221c01d.1580.46b7.bdde.45844fd986ac 6261
# 591ee23e.56bf.4275.8630.9015f9f330a5 6565
# b1603450.fce3.449f.88a5.38041fecbc22 7055
# c87aa886.d2cf.432a.b38b.f40c01cb1965 7202
# fdefd7b2.abfd.4eb8.9e8d.c847d67ee8c4 7271
# 447cc359.470e.4d74.ba9c.318b733e8d1f 7751
# 5b24f7ea.9e02.4d89.bc02.03388ed68273 8509
# ...
